# %% [markdown]
# ## Random Reaction Networks
#
# #### Early implementation of random networks of reactions that are **thermodynamically possible**,
# #### and **biologically plausible**

# %% [markdown]
# ### TAGS :   "uniform compartment"

# %%
LAST_REVISED = "July 13, 2026"
LIFE123_VERSION = "1.0.0rc8"         # Library version this experiment is based on

# %%
#import set_path            # Using MyBinder?  Uncomment this before running the next cell!
                            # Importing this module will add the project's home directory to sys.path

# %%
#import sys, os
#os.getcwd()
#sys.path.append("C:/some_path/my_env_or_install")   # CHANGE to the folder containing your venv or libraries installation!
# NOTE: If any of the imports below can't find a module, uncomment the lines above, or try:  import set_path

import ipynbname
from IPython.display import IFrame

from life123 import check_version, RandomReactionNetwork, UniformCompartment

# %%
check_version(LIFE123_VERSION)    # To check compatibility
# Out:
# OK

# %%
# Initialize the HTML logging (for the graphics)
log_file = ipynbname.name() + ".log.htm"    # Use the notebook base filename for the log file
                                            # IN CASE OF PROBLEMS, set manually to any desired name
log_file
# Out:
# 'random_networks_1.log.htm'

# %% [markdown]
# ## Set up Random Network

# %%
net = RandomReactionNetwork(n_species=4, n_rxns=7, seed=47242315, thermodynamic_ruggedness=0.2)

# %%
net.species_data.get_all_species_ids()
# Out:
# ['A', 'B', 'C', 'D']

# %% [markdown]
# #### The above chemical labels were auto-generated

# %%
rxns = net.get_reaction_data()          # Object of type "ReactionRegistry"

# %%
rxns.number_of_reactions()
# Out:
# 7

# %%
rxns.describe_reactions()
# Out:
# Number of reactions: 7
# 0: C <-> A + D  Elementary Decomposition reaction  (kF = 3,783.6 | kR = 0.0097904 | delta_H = -16.262 kJ/mol | delta_S = 52.421 J/(mol·K) | delta_G = -31.891 kJ/mol | K = 3.8646e+05 | Temp = 25 C)
# 1: 2 C  <-> D  Elementary Synthesis reaction  (kF = 0.36677 | kR = 13.455 | delta_H = -8.9575 kJ/mol | delta_S = -59.996 J/(mol·K) | delta_G = 8.9301 kJ/mol | K = 0.027259 | Temp = 25 C)
# 2: B + C  <-> D  Elementary Synthesis reaction  (kF = 0.005396 | kR = 2.4995 | delta_H = -9.2274 kJ/mol | delta_S = -81.985 J/(mol·K) | delta_G = 15.216 kJ/mol | K = 0.0021588 | Temp = 25 C)
# 3: B <-> 2 D  Elementary Decomposition reaction  (kF = 9.0076 | kR = 0.074841 | delta_H = -8.6745 kJ/mol | delta_S = 10.735 J/(mol·K) | delta_G = -11.875 kJ/mol | K = 120.36 | Temp = 25 C)
# 4: D <-> A + B  Elementary Decomposition reaction  (kF = 168.03 | kR = 0.012614 | delta_H = -4.4174 kJ/mol | delta_S = 64.147 J/(mol·K) | delta_G = -23.543 kJ/mol | K = 13,321 | Temp = 25 C)
# 5: A + D  <-> B  Elementary Synthesis reaction  (kF = 0.00043468 | kR = 36.338 | delta_H = 16.532 kJ/mol | delta_S = -38.786 J/(mol·K) | delta_G = 28.096 kJ/mol | K = 1.1962e-05 | Temp = 25 C)
# 6: D + C  <-> A  Elementary Synthesis reaction  (kF = 51.723 | kR = 53.646 | delta_H = -11.028 kJ/mol | delta_S = -37.29 J/(mol·K) | delta_G = 0.090492 kJ/mol | K = 0.96415 | Temp = 25 C)
# Chemicals involved in the above reactions: {"A", "B", "C", "D"}

# %% [markdown]
# ## NOTE ON UNITS: _delta_H_ and _delta_G_ are in **kJ/mol**  ;  _delta_S_ are in **J/(mol·K)**

# %% [markdown]
# #### Investigate the random values that were assigned to the reactions (in a manner to be consistent with thermodynamics, for example across groups of reactions):

# %%
H_list = [rxn.delta_H
              for rxn in net.get_reaction_data().get_all_reactions()]
H_list   # kJ/mol
# Out:
# [-16.262093710585276,
#  -8.95754366062873,
#  -9.227408711383152,
#  -8.674548248998072,
#  -4.417410753915934,
#  16.5319587613397,
#  -11.027545220012897]

# %%
S_list = [rxn.delta_S
              for rxn in net.get_reaction_data().get_all_reactions()]
S_list   # J/(mol·K)
# Out:
# [52.42053331751184,
#  -59.995529512556274,
#  -81.98455786740513,
#  10.735492461211042,
#  64.14701422039786,
#  -38.78571157151433,
#  -37.290078736939144]

# %%
G_list = [rxn.delta_G
              for rxn in net.get_reaction_data().get_all_reactions()]
G_list   # kJ/mol
# Out:
# [-31.89127571920143,
#  8.930123463539921,
#  15.216287216783687,
#  -11.875335326308143,
#  -23.542843043727558,
#  28.095918666386694,
#  0.09049175540550891]

# %%
# Verify G_list
[H_list[i] - (25+273.15) * S_list[i] / 1000 for i in range(len(H_list))]
# Out:
# [-31.89127571920143,
#  8.930123463539921,
#  15.216287216783687,
#  -11.875335326308143,
#  -23.542843043727558,
#  28.095918666386694,
#  0.09049175540550891]

# %%
# Instantiate the simulator with our chemicals and reactions
uc = UniformCompartment(reactions=rxns)

# %%
# Send a plot of the network of reactions to the HTML log file
uc.plot_reaction_network(log_file=log_file)
# Out:
# [GRAPHIC ELEMENT SENT TO FILE `random_networks_1.log.htm`]

# %%
IFrame(log_file, width=1200, height=700)         # You may also open the log file in a browser
# Out:
#         <iframe
#             width="1200"
#             height="700"
#             src="random_networks_1.log.htm"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
