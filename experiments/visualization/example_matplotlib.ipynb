# %% [markdown]
# **TEST OF matplotlib**

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Data for plotting
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

# %%
plt.plot(t, s)
